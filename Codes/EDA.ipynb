# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
airlines = pd.read_csv("airlines.csv")
airports = pd.read_csv("airports.csv")
train = pd.read_csv("flights_train.csv")
test = pd.read_csv("flights_test.csv")
submit_sample = pd.read_csv("submit_sample.csv")

# %%
# Correlation matrix
corr = train.corr()
sns.heatmap(corr, vmin=-1, vmax=1, center=0, square=True)
# Out:
# <AxesSubplot:>

# %%
# Duplicate records
duprec = train[train.duplicated()]
print("Number of duplicate records: ", duprec.shape)
# Out:
# Number of duplicate records:  (0, 18)

# %%
# Column analysis function
def outlierDetect(df, col):
    q1 = col.quantile(.25)
    q3 = col.quantile(.75)

    IQR = q3-q1
    lower_limit = q1-(1.5*IQR)
    upper_limit = q3+(1.5*IQR)

    ol = []
    for val in col:
        if val < lower_limit or val > upper_limit:
            ol.append(val)
    
    return len(ol)
    
def plotChart(col):
    fix, (ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
    sns.boxplot(col,orient='v',ax=ax1)
    ax1.set_ylabel = col.name
    ax1.set_title("Box plot of {}".format(col.name))
    sns.distplot(col, ax=ax2)
    ax2.set_title("Distribution of {}".format(col.name))

def col_analysis(df, col):
    print("*****Column name: {} *****".format(col.name))
    print("Outliers: ", outlierDetect(df, col))
    print("Min: ", format(np.min(col)))    
    print("Mean: ", format(round(np.mean(col),2)))
    print("Median: ", format(np.median(col)))
    print("std: ", format(round(np.std(col),2)))    
    print("Max: ", format(np.max(col)))
    print("Missing values: ", format(col.isnull().sum()))
    print("% of Missing values: ", format(round((col.isnull().sum()/len(col))*100, 2)))
    plotChart(col)

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numcols = train.select_dtypes(include=numerics)
collst = list(numcols)

for col in collst:
    col_analysis(train, train[col])

#col_analysis(train, train.ARRIVAL_DELAY)
#col_analysis(train, train.SCHEDULED_ARRIVAL)
# Out:
# *****Column name: id *****
# Outliers:  0
# Min:  0
# Mean:  1409276.0
# Median:  1409276.0
# std:  813646.17
# Max:  2818552
# Missing values:  0
# % of Missing values:  0.0
# C:\Users\Maud\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Maud\anaconda3\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %%
# Which day of the week most arrival delays happens?

wk = train[['DAY_OF_WEEK', 'ARRIVAL_DELAY']]
wk = wk[wk['ARRIVAL_DELAY']>0]
wk = wk.groupby(['DAY_OF_WEEK'])['ARRIVAL_DELAY'].size().reset_index(name='ARRIVAL_DELAY_COUNTS')

sns.barplot(
    x=wk.DAY_OF_WEEK, 
    y=wk.ARRIVAL_DELAY_COUNTS, 
    order=wk.sort_values('ARRIVAL_DELAY_COUNTS',ascending = False).DAY_OF_WEEK,
    ci=None)
# Out:
# <AxesSubplot:xlabel='DAY_OF_WEEK', ylabel='ARRIVAL_DELAY_COUNTS'>

# %%
# Which month of the year has highest arrival delay?

mnth = train[['MONTH', 'ARRIVAL_DELAY']]
mnth = mnth[mnth['ARRIVAL_DELAY']>0]
mnth = mnth.groupby(['MONTH'])['ARRIVAL_DELAY'].size().reset_index(name='ARRIVAL_DELAY_COUNTS')

sns.barplot(
    x=mnth.MONTH, 
    y=mnth.ARRIVAL_DELAY_COUNTS, 
    order=mnth.sort_values('ARRIVAL_DELAY_COUNTS',ascending = False).MONTH,
    ci=None)
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='ARRIVAL_DELAY_COUNTS'>

# %%
# Which airline is experiencing highest median arrival delay?

arln = pd.merge(train, airlines, left_on='AIRLINE', right_on='IATA_CODE')
arln = arln.drop(['IATA_CODE'], axis=1)
arln.rename({'AIRLINE_x':'AIRLINE_CODE', 'AIRLINE_y':'AIRLINE_NAME'}, axis=1, inplace=True)
#arln.head()

arln_arr = arln[arln['ARRIVAL_DELAY']>0]
arln_arr = arln_arr[['AIRLINE_NAME', 'ARRIVAL_DELAY']]
arln_arrmed = arln_arr.groupby(['AIRLINE_NAME'])['ARRIVAL_DELAY'].median().reset_index()
arln_arrcnt = arln_arr.groupby(['AIRLINE_NAME'])['ARRIVAL_DELAY'].size().reset_index(name='ARRIVAL_DELAY_COUNTS')
#arln_arr.head(20)

fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.barplot(
    x=arln_arrmed.ARRIVAL_DELAY, 
    y=arln_arrmed.AIRLINE_NAME, 
    order=arln_arrmed.sort_values('ARRIVAL_DELAY',ascending = False).AIRLINE_NAME,
    ci=None,
    ax=axes[0]
)
sns.barplot(
    x=arln_arrcnt.ARRIVAL_DELAY_COUNTS, 
    y=arln_arrcnt.AIRLINE_NAME, 
    order=arln_arrcnt.sort_values('ARRIVAL_DELAY_COUNTS',ascending = False).AIRLINE_NAME,
    ci=None,
    ax=axes[1]
)

fig.tight_layout()

# %%
# Is the same airline is experiencing highest median departure delay?

arln['DEPARTURE_DELAY'] = arln['DEPARTURE_TIME'] - arln['SCHEDULED_DEPARTURE']
arln_dep = arln[arln['DEPARTURE_DELAY']>0]
arln_dep = arln_dep[['AIRLINE_NAME', 'DEPARTURE_DELAY']]
arln_depmed = arln_dep.groupby(['AIRLINE_NAME'])['DEPARTURE_DELAY'].median().reset_index()
arln_depcnt = arln_dep.groupby(['AIRLINE_NAME'])['DEPARTURE_DELAY'].size().reset_index(name='DEPARTURE_DELAY_COUNTS')
sns.color_palette("mako", as_cmap=True)
fig, axes = plt.subplots(1,2, figsize=(15,5))
sns.barplot(
    x=arln_depmed.DEPARTURE_DELAY, 
    y=arln_depmed.AIRLINE_NAME, 
    order=arln_depmed.sort_values('DEPARTURE_DELAY',ascending = False).AIRLINE_NAME,
    ci=None,
    palette ="mako",
    ax=axes[0]
)
sns.barplot(
    x=arln_depcnt.DEPARTURE_DELAY_COUNTS, 
    y=arln_depcnt.AIRLINE_NAME, 
    order=arln_depcnt.sort_values('DEPARTURE_DELAY_COUNTS',ascending = False).AIRLINE_NAME,
    ci=None,
    palette = "mako",
    ax=axes[1]
)

fig.tight_layout()

# %%
# Top 10 origin airports reporting highest number of delays

# arpt_temp = airports[['IATA_CODE', 'AIRPORT']]
# oarpt = pd.merge(train, arpt_temp, left_on='ORIGIN_AIRPORT', right_on='IATA_CODE')
# oarpt = oarpt.drop(['IATA_CODE'], axis=1)
# oarpt.rename({'ORIGIN_AIRPORT':'ORIGIN_AIRPORT_CODE', 'AIRPORT':'ORIGIN_AIRPORT'}, axis=1, inplace=True)
# oarpt.head()

oarpt_plt = oarpt[['ORIGIN_AIRPORT', 'ARRIVAL_DELAY']]
oarpt_plt = oarpt_plt[oarpt_plt['ARRIVAL_DELAY']>0]
oarpt_plt = oarpt_plt.groupby(['ORIGIN_AIRPORT'])['ARRIVAL_DELAY'].size().reset_index(name='ARRIVAL_DELAY_COUNTS')
oarpt_plt = oarpt_plt.sort_values(by=['ARRIVAL_DELAY_COUNTS'], ascending=False)
oarpt_plt = oarpt_plt[0:10]

sns.barplot(
    x=oarpt_plt.ARRIVAL_DELAY_COUNTS,
    y=oarpt_plt.ORIGIN_AIRPORT, 
    order=oarpt_plt.sort_values('ARRIVAL_DELAY_COUNTS',ascending = False).ORIGIN_AIRPORT,
    ci=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c38d7947477a> in <module>
#       7 # oarpt.head()
#       8
# ----> 9 oarpt_plt = oarpt[['ORIGIN_AIRPORT', 'ARRIVAL_DELAY']]
#      10 oarpt_plt = oarpt_plt[oarpt_plt['ARRIVAL_DELAY']>0]
#      11 oarpt_plt = oarpt_plt.groupby(['ORIGIN_AIRPORT'])['ARRIVAL_DELAY'].size().reset_index(name='ARRIVAL_DELAY_COUNTS')
#
# NameError: name 'oarpt' is not defined

# %%
# Top 10 destination airports reporting highest number of delays

# arpt_temp = airports[['IATA_CODE', 'AIRPORT']]
# darpt = pd.merge(train, arpt_temp, left_on='DESTINATION_AIRPORT', right_on='IATA_CODE')
# darpt = darpt.drop(['IATA_CODE'], axis=1)
# darpt.rename({'DESTINATION_AIRPORT':'DESTINATION_AIRPORT_CODE', 'AIRPORT':'DESTINATION_AIRPORT'}, axis=1, inplace=True)

darpt_plt = darpt[['DESTINATION_AIRPORT', 'ARRIVAL_DELAY']]
darpt_plt = darpt_plt[darpt_plt['ARRIVAL_DELAY']>0]
darpt_plt = darpt_plt.groupby(['DESTINATION_AIRPORT'])['ARRIVAL_DELAY'].size().reset_index(name='ARRIVAL_DELAY_COUNTS')
darpt_plt = darpt_plt.sort_values(by=['ARRIVAL_DELAY_COUNTS'], ascending=False)
darpt_plt = darpt_plt[0:10]

sns.barplot(
    x=darpt_plt.ARRIVAL_DELAY_COUNTS,
    y=darpt_plt.DESTINATION_AIRPORT, 
    order=darpt_plt.sort_values('ARRIVAL_DELAY_COUNTS',ascending = False).DESTINATION_AIRPORT,
    ci=None)

# %%
# Top 10 origin & destination pair airports reporting highest number of delays


# arpt_temp = airports[['IATA_CODE', 'AIRPORT']]

# Joining on destination airport
# arpt = pd.merge(train, arpt_temp, left_on='DESTINATION_AIRPORT', right_on='IATA_CODE')
# arpt = arpt.drop(['IATA_CODE'], axis=1)
# arpt.rename({'DESTINATION_AIRPORT':'DESTINATION_AIRPORT_CODE', 'AIRPORT':'DESTINATION_AIRPORT'}, axis=1, inplace=True)

# Joining on origin airport 
# arpt = pd.merge(arpt, arpt_temp, left_on='ORIGIN_AIRPORT', right_on='IATA_CODE')
# arpt = arpt.drop(['IATA_CODE'], axis=1)
# arpt.rename({'ORIGIN_AIRPORT':'ORIGIN_AIRPORT_CODE', 'AIRPORT':'ORIGIN_AIRPORT'}, axis=1, inplace=True)

# Making pair variable
# arpt['AIRPORT_PAIR'] = arpt['ORIGIN_AIRPORT'] + ' -> ' + arpt['DESTINATION_AIRPORT']

#arpt.head()

arpt_plt = arpt[['AIRPORT_PAIR', 'ARRIVAL_DELAY']]
arpt_plt = arpt_plt[arpt_plt['ARRIVAL_DELAY']>0]
arpt_plt = arpt_plt.groupby(['AIRPORT_PAIR'])['ARRIVAL_DELAY'].size().reset_index(name='ARRIVAL_DELAY_COUNTS')
arpt_plt = arpt_plt.sort_values(by=['ARRIVAL_DELAY_COUNTS'], ascending=False)
arpt_plt = arpt_plt[0:10]

sns.barplot(
    x=arpt_plt.ARRIVAL_DELAY_COUNTS,
    y=arpt_plt.AIRPORT_PAIR, 
    order=arpt_plt.sort_values('ARRIVAL_DELAY_COUNTS',ascending = False).AIRPORT_PAIR,
